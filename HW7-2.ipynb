# %% [markdown]
# 1

# %% [markdown]
# Последовательности, которые я взяла:
# •  Спайк-белки коронавирусов (Spike glycoproteins). Спайк-белок — это ключевой белок на поверхности вируса, который позволяет ему проникать в клетки-хозяева. Последовательности включают в себя:
# •  OZ022790.1: Severe acute respiratory syndrome coronavirus 2 partial S gene for SARS-CoV-2 Spike Protein, isolate 1
# •  OP173215.1: Severe acute respiratory syndrome coronavirus 2 isolate SARS-CoV-2/human/MLI/Wuhan-Hu-1-148/2021 surface glycoprotein (S) gene, complete cds
# •  ON080548.1: Severe acute respiratory syndrome coronavirus 2 isolate SARS-CoV-2/human/SWE/W/2020 surface glycoprotein (S) gene, complete cds

# %% [markdown]
# Дерево, которое получила (числа - последовательности с семинара):

# %%
from IPython.display import Image
Image(filename='122.png')

# %% [markdown]
# Последовательности s-белка  с семинара отличаются от других образцов SARS-CoV-2.

# %% [markdown]
# 2

# %% [markdown]
# Я взяла последовательности гена TUBA1A (тубулин альфа 1A) у следующих организмов:
#
# •  Homo sapiens (человек)
# •  Mus musculus (мышь)
# •  Rattus norvegicus (крыса)
# •  Macaca mulatta (макака-резус)
# •  Xenopus tropicalis (шпорцевая лягушка)
# •  Capra hircus (коза)
# •  Marmota marmota marmota (европейский сурок)
# •  Pseudonaja textilis (восточная коричневая змея)
# •  Cygnus olor (лебедь-шипун)
# •  Panthera leo (лев)

# %%
from IPython.display import Image
Image(filename='000.png')

# %% [markdown]
# Этот кладограмма показывает, что последовательности тубулина альфа 1a (TUBA1A) различаются между видами. Наиболее близки по TUBA1A человек, макака, затем идет группа животных: мармота, коза, пантера, мышь, крыса. Дальше уже идут более отличающиеся животные: змея, лягушка и лебедь.
