# %% [markdown]
# Задача 1

# %%
from IPython.display import Image
Image(filename='333.png')

# %% [markdown]
# Для файла SRR17307316fastq был проведен fastaQC анализ
# Общее качество нормальное - нет резких провалов
# ридов с качеством <20 нет
# после 10 bp состав A/T и G/C стабилизируется
# GC-состав близок к теоретическому

# %% [markdown]
# Задача 2

# %% [markdown]
# Параметр --p-trim-left 25 используется для обрезки первых 25 нуклеотидов с 5’-конца
# Это нужно поскольку начало ридов часто имеют низкое качество

# %% [markdown]
# Задача 3

# %% [markdown]
# Результаты визуализации
# a) доля оставшихся прочтений от 89 до 97%
# b) самый маленький образец - 4809 прочтений
# c) самый большой образец - 43518 прочтений
# d) высокий коэффициент сохранения говорит о минимальных потерях при
# фильтрации
# e) большой разброс (почти в 9 раз) - разная биомасса в образцах или
# вариабельной микробного сообщества

# %% [markdown]
# Задача 4

# %%
Праймер начинает амплификацию в регионе V4 и большая часть
амплифицированной последовательности приходится тоже на регион V4 (а мы
используем только прямые риды) → используем классификатор обученный
только на V4

# %% [markdown]
# Задача 5

# %% [markdown]
# Результаты распределения классов
# a) в первой временной точке образцы похожи
# b) с течением времени растет число Gammaproteobacteria
# c) в t1 самые частые группы: Acidobacteriae, Gammaproteobacteria,
# Alphaproteobacteria, Actinomycetia
# d) в t4 в основном остались Gammaproteobacteria и немного
# Alphaproteobacteria
# e) Самый частый род в образцах - Acidoferrum, а при добавлении керосина
# увеличивается содержание Paraburkholderia
# f) такое наблюдение вполне ожидаемо: Acidoferrum -
# железовосстанавливающие бактерии, обитающие в почвах и их наличие
# особенно в контрольных образцах логично; Paraburkholderia - разлагают
# ароматические соединения и их метаболизм довольно гибкий, поэтому
# они и составляют подавляющее большинство организмов к концу
# эксперимента

# %%
from IPython.display import Image
Image(filename='444.png')

# %%
from IPython.display import Image
Image(filename='555.png')

# %% [markdown]
# Подходящая глубина - 4800

# %% [markdown]
# Задача 6

# %%
from IPython.display import Image
Image(filename='666.png')

# %% [markdown]
# a) образцы одной временной точки находятся близко друг к другу
# (например d3) - это говорит о сходстве образцов в начальной точке
# b) с течением времени точки сдвигаются вдоль оси Axis1, а иногда и оси
# Axis2 - изменение состава
# c) При слабом загрязнении видны признаки восстановления (видно
# приближение к контролю)
# d) При сильном загрязнении восстановление менее выражено

# %% [markdown]
# Задача 7

# %%
from IPython.display import Image
Image(filename='777.png')

# %% [markdown]
# В контроле: незначительное снижение разнообразия (
# k5 - снижение разнообразие наблюдается с течением времени, однако к
# t4 наблюдается восстановление
# k25 - снижение более “активное” и восстановления не наблюдается
